# %%
# pip list --format=freeze > requirements.txt
# pip install -r requirements.txt

# %%
# %matplotlib inline

# %%
import torch
import pandas as pd
import numpy as np
import os
from transformers import pipeline
from datetime import datetime

# from sklearn.svm import SVC
# from sklearn.datasets import load_digits
# from sklearn.feature_selection import RFE
import matplotlib.pyplot as plt

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
path = "/Users/emilygong/Desktop/RUW-Oil-Prediction/data"
os.chdir(path)

# %% [markdown]
# # Read in the Dataset

# %% [markdown]
# ## News

# %%
guardian = pd.read_csv("Guardian_articles.csv")
guardian = guardian[['webPublicationDate', 'webTitle']]
guardian.columns = ['date', 'title']

nyt = pd.read_csv("NYT_articles.csv")
nyt = nyt[['pub_date', 'headline']]
nyt.columns = ['date', 'title']

# %%
def clean(string):
    main = string.find("'main':")
    comma = string.find("',")
    return string[main+9:comma+1]

nyt['title'] = nyt['title'].apply(clean)
nyt = nyt[nyt['title'] != '']

# %%
def select(string):
    return string[0:10]

guardian['date'] = guardian['date'].apply(select)
nyt['date'] = nyt['date'].apply(select)

# %%
final = pd.concat([guardian, nyt])

# %% [markdown]
# ## Stock

# %%
oil_price = pd.read_csv("Oil_price.csv")
oil_price['date'] = pd.to_datetime(oil_price['date'])
oil_price = oil_price[oil_price['date'] >= datetime(2022, 2,1)]

oil_price_more = pd.read_csv("Cushing_OK_WTI_Spot_Price_FOB.csv")
oil_price_more['date'] = pd.to_datetime(oil_price_more['date'])
oil_price_test = oil_price_more[oil_price_more['date'] >= datetime(2022, 2, 1)]
oil_price_test.index = oil_price_test['date']
oil_price_test = oil_price_test[['price']]

# %% [markdown]
# ## Apply sentiment & Text/Emotion Classifier

# %%
sentiment = pipeline("sentiment-analysis", model = "distilbert-base-uncased-finetuned-sst-2-english")
classifier = pipeline("text-classification", model='bhadresh-savani/distilbert-base-uncased-emotion', top_k=None)

# %%
titles = final['title'].to_list()

label = []
score = []

anger = []
fear = []
joy = []
sadness = []
love = []
surprise = []

for title in titles:
    result = sentiment(title)
    label.append(result[0]['label'])
    score.append(result[0]['score'])
for title in titles:
    result = classifier(title)
    anger.append(result[0][0]['score'])
    fear.append(result[0][1]['score'])
    joy.append(result[0][2]['score'])
    sadness.append(result[0][3]['score'])
    love.append(result[0][4]['score'])
    surprise.append(result[0][5]['score'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [206], line 14
#      11 surprise = []
#      13 for title in titles:
# ---> 14     result = sentiment(title)
#      15     label.append(result[0]['label'])
#      16     score.append(result[0]['score'])
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:140, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     106 def __call__(self, *args, **kwargs):
#     107     """
#     108     Classify the text(s) given as inputs.
#     109
#    (...)
#     138         If `top_k` is used, one such dictionary is returned per label.
#     139     """
# --> 140     result = super().__call__(*args, **kwargs)
#     141     # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     142     _legacy = "top_k" not in kwargs
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/pipelines/base.py:1074, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1072     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1073 else:
# -> 1074     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/pipelines/base.py:1081, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1079 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1080     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1081     model_outputs = self.forward(model_inputs, **forward_params)
#    1082     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1083     return outputs
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/pipelines/base.py:990, in Pipeline.forward(self, model_inputs, **forward_params)
#     988     with inference_context():
#     989         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 990         model_outputs = self._forward(model_inputs, **forward_params)
#     991         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     992 else:
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:167, in TextClassificationPipeline._forward(self, model_inputs)
#     166 def _forward(self, model_inputs):
# --> 167     return self.model(**model_inputs)
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:747, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     739 r"""
#     740 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     741     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     742     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     743     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     744 """
#     745 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 747 distilbert_output = self.distilbert(
#     748     input_ids=input_ids,
#     749     attention_mask=attention_mask,
#     750     head_mask=head_mask,
#     751     inputs_embeds=inputs_embeds,
#     752     output_attentions=output_attentions,
#     753     output_hidden_states=output_hidden_states,
#     754     return_dict=return_dict,
#     755 )
#     756 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     757 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:567, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     565 if inputs_embeds is None:
#     566     inputs_embeds = self.embeddings(input_ids)  # (bs, seq_length, dim)
# --> 567 return self.transformer(
#     568     x=inputs_embeds,
#     569     attn_mask=attention_mask,
#     570     head_mask=head_mask,
#     571     output_attentions=output_attentions,
#     572     output_hidden_states=output_hidden_states,
#     573     return_dict=return_dict,
#     574 )
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:345, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     342 if output_hidden_states:
#     343     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 345 layer_outputs = layer_module(
#     346     x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     347 )
#     348 hidden_state = layer_outputs[-1]
#     350 if output_attentions:
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:283, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     273 """
#     274 Parameters:
#     275     x: torch.tensor(bs, seq_length, dim)
#    (...)
#     280     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     281 """
#     282 # Self-Attention
# --> 283 sa_output = self.attention(
#     284     query=x,
#     285     key=x,
#     286     value=x,
#     287     mask=attn_mask,
#     288     head_mask=head_mask,
#     289     output_attentions=output_attentions,
#     290 )
#     291 if output_attentions:
#     292     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:206, in MultiHeadSelfAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     203     return x.transpose(1, 2).contiguous().view(bs, -1, self.n_heads * dim_per_head)
#     205 q = shape(self.q_lin(query))  # (bs, n_heads, q_length, dim_per_head)
# --> 206 k = shape(self.k_lin(key))  # (bs, n_heads, k_length, dim_per_head)
#     207 v = shape(self.v_lin(value))  # (bs, n_heads, k_length, dim_per_head)
#     209 q = q / math.sqrt(dim_per_head)  # (bs, n_heads, q_length, dim_per_head)
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:199, in MultiHeadSelfAttention.forward.<locals>.shape(x)
#     197 def shape(x: torch.Tensor) -> torch.Tensor:
#     198     """separate heads"""
# --> 199     return x.view(bs, -1, self.n_heads, dim_per_head).transpose(1, 2)
#
# KeyboardInterrupt:

# %%
final['label'] = label
final['score'] = score

final['anger'] = anger
final['fear'] = fear
final['joy'] = joy
final['sadness'] = sadness
final['love'] = love
final['surprise'] = surprise

# %%
final['date'] = pd.to_datetime(final['date'])

# %% [markdown]
# ## Read in the outputted csv

# %%
# final.to_csv('final.csv', index = False)
final = pd.read_csv('final.csv')
final['date'] = pd.to_datetime(final['date'])

# %% [markdown]
# # Aggregate News Emotion by Day

# %%
df_by_day = final.set_index("date").groupby(pd.Grouper(freq='D')).mean().reset_index()
# df_by_day = df_by_day.loc[df_by_day['date'] > datetime(2022, 3, 1)]
# Out:
# /var/folders/9f/07hlwdb51gggdsry0cqd7rdw0000gn/T/ipykernel_8928/1558793010.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_by_day = final.set_index("date").groupby(pd.Grouper(freq='D')).mean().reset_index()

# %%
df_by_day = df_by_day.dropna().reset_index(drop=True)
df_by_day = df_by_day[df_by_day['date'] >= datetime(2022, 2,1)]

# %%
df_by_day = df_by_day[['date', 'anger', 'fear', 'joy', 'sadness', 'love', 'surprise']]

# %%
price = pd.merge(df_by_day, oil_price, on = 'date')
price_full = pd.merge(df_by_day, oil_price_test, on = 'date', how = "right")
price.to_csv("price.csv")
price_full.to_csv("price_full.csv")

# %% [markdown]
# # Simple Plots

# %%
price = price.set_index('date')
price.plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
plt.plot('price', data = price)

# %%
plt.plot('anger', data = price)
plt.plot('fear', data = price)
plt.plot('joy', data = price)
plt.plot('sadness', data = price)
plt.plot('love', data = price)
plt.plot('surprise', data = price)
plt.legend()
