# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pred_len= [24, 48, 96, 192, 336, 720]
mse = [0.004060422070324421, 0.009142586030066013, 0.016673797741532326, 0.02819044142961502, 0.03822814300656319, 0.08157696574926376]

# %%
plt.plot(pred_len, mse, marker = 'o')
plt.xlabel("Forecasting Length")
plt.ylabel("MSE")
plt.title("with Fixed Look-back Window (336)")
# Out:
# Text(0.5, 1.0, 'with Fixed Look-back Window (336)')
